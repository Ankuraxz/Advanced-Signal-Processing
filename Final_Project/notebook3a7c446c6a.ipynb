# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory


# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import cv2
import numpy as np
from sklearn.preprocessing import StandardScaler
from skimage import exposure, filters
# set the random seed for reproducibility
np.random.seed(42)

# set the image size and batch size
img_size = (224, 224)
batch_size = 64

# %%
import os
import sys
os.chdir("/kaggle/input/chest-xray-pneumonia/chest_xray")
os.listdir()

train_path = "/kaggle/input/chest-xray-pneumonia/chest_xray/train"
val_path = "/kaggle/input/chest-xray-pneumonia/chest_xray/val"
test_path = "/kaggle/input/chest-xray-pneumonia/chest_xray/test"

# %%
os.mkdir("/kaggle/working/chest-xray-pneumonia")
os.mkdir("/kaggle/working/chest-xray-pneumonia/chest_xray")
os.mkdir("/kaggle/working/chest-xray-pneumonia/chest_xray/train")
os.mkdir("/kaggle/working/chest-xray-pneumonia/chest_xray/test")

# %%
def preprocess(img):
    img_resized = cv2.resize(img, (224, 224))
    img_sharpened = cv2.GaussianBlur(img_resized, (5,5), 0)
    img_sharpened = cv2.addWeighted(img_resized, 1.5, img_sharpened, -0.5, 0)

            # apply a median filter to the image
    img_median = filters.median(img_sharpened) 
    return(img_median)

# %%
os.rmdir('/kaggle/working/chest-xray-pneumonia/chest_xray/test/PNEUMONIA')

# %%
for category in os.listdir(test_path):
    os.chdir(os.path.join(test_path,category))
    pathf = os.path.join("/kaggle/working/chest-xray-pneumonia/chest_xray/test",category)
    os.mkdir(pathf)
    print(category)
    
    for ix in os.listdir(): #Images
            img = cv2.imread(ix)
            img_median = preprocess(img)
            filename1 = str(pathf)+"/"+ix
            filename2 = str(pathf)+"/"+"modified_"+ix
#             cv2.imwrite(filename1,img)
            cv2.imwrite(filename2,img_median) # Saving Modified Image
            print(str(ix+"saved"))
# Out:
# PNEUMONIA
# person1676_virus_2892.jpegsaved
# person1650_virus_2852.jpegsaved
# person22_virus_55.jpegsaved
# person122_bacteria_582.jpegsaved
# person85_bacteria_417.jpegsaved
# person79_virus_148.jpegsaved
# person29_virus_64.jpegsaved
# person123_bacteria_587.jpegsaved
# person75_virus_136.jpegsaved
# person153_bacteria_725.jpegsaved
# person173_bacteria_831.jpegsaved
# person16_virus_47.jpegsaved
# person138_bacteria_659.jpegsaved
# person112_bacteria_538.jpegsaved
# person83_bacteria_409.jpegsaved
# person23_virus_56.jpegsaved
# person80_bacteria_392.jpegsaved
# person140_bacteria_667.jpegsaved
# person3_virus_17.jpegsaved
# person97_bacteria_468.jpegsaved
# person1_virus_11.jpegsaved
# person83_bacteria_410.jpegsaved
# person127_bacteria_604.jpegsaved
# person121_bacteria_578.jpegsaved
# person1650_virus_2854.jpegsaved
# person21_virus_52.jpegsaved
# person82_bacteria_402.jpegsaved
# person1685_virus_2903.jpegsaved
# person82_bacteria_403.jpegsaved
# person26_virus_60.jpegsaved
# person1663_virus_2876.jpegsaved
# person77_virus_139.jpegsaved
# person1619_virus_2806.jpegsaved
# person136_bacteria_654.jpegsaved
# person157_bacteria_740.jpegsaved
# person19_virus_50.jpegsaved
# person80_bacteria_391.jpegsaved
# person96_bacteria_464.jpegsaved
# person139_bacteria_662.jpegsaved
# person1672_virus_2888.jpegsaved
# person111_bacteria_535.jpegsaved
# person128_bacteria_607.jpegsaved
# person87_bacteria_433.jpegsaved
# person157_bacteria_739.jpegsaved
# person121_bacteria_580.jpegsaved
# person158_bacteria_745.jpegsaved
# person99_bacteria_473.jpegsaved
# person3_virus_15.jpegsaved
# person91_bacteria_446.jpegsaved
# person114_bacteria_544.jpegsaved
# person175_bacteria_835.jpegsaved
# person111_bacteria_534.jpegsaved
# person66_virus_125.jpegsaved
# person152_bacteria_723.jpegsaved
# person78_bacteria_384.jpegsaved
# person78_virus_140.jpegsaved
# person122_bacteria_581.jpegsaved
# person118_bacteria_560.jpegsaved
# person158_bacteria_743.jpegsaved
# person94_bacteria_457.jpegsaved
# person147_bacteria_706.jpegsaved
# person1661_virus_2872.jpegsaved
# person1614_virus_2800.jpegsaved
# person117_bacteria_553.jpegsaved
# person1628_virus_2822.jpegsaved
# person113_bacteria_543.jpegsaved
# person150_bacteria_715.jpegsaved
# person55_virus_110.jpegsaved
# person122_bacteria_586.jpegsaved
# person1656_virus_2862.jpegsaved
# person102_bacteria_487.jpegsaved
# person93_bacteria_454.jpegsaved
# person141_bacteria_677.jpegsaved
# person134_bacteria_644.jpegsaved
# person90_bacteria_443.jpegsaved
# person20_virus_51.jpegsaved
# person1637_virus_2834.jpegsaved
# person133_bacteria_634.jpegsaved
# person155_bacteria_729.jpegsaved
# person56_virus_112.jpegsaved
# person1645_virus_2845.jpegsaved
# person1632_virus_2827.jpegsaved
# person28_virus_63.jpegsaved
# person120_bacteria_572.jpegsaved
# person128_bacteria_605.jpegsaved
# person159_bacteria_746.jpegsaved
# person46_virus_96.jpegsaved
# person117_bacteria_557.jpegsaved
# person131_bacteria_629.jpegsaved
# person114_bacteria_546.jpegsaved
# person91_bacteria_448.jpegsaved
# person173_bacteria_830.jpegsaved
# person1635_virus_2831.jpegsaved
# person1610_virus_2793.jpegsaved
# person45_virus_95.jpegsaved
# person125_bacteria_594.jpegsaved
# person125_bacteria_595.jpegsaved
# person95_bacteria_463.jpegsaved
# person141_bacteria_678.jpegsaved
# person109_bacteria_512.jpegsaved
# person111_bacteria_533.jpegsaved
# person149_bacteria_713.jpegsaved
# person28_virus_62.jpegsaved
# person175_bacteria_833.jpegsaved
# person128_bacteria_606.jpegsaved
# person1644_virus_2844.jpegsaved
# person143_bacteria_687.jpegsaved
# person101_bacteria_483.jpegsaved
# person32_virus_71.jpegsaved
# person100_bacteria_477.jpegsaved
# person90_bacteria_442.jpegsaved
# person96_bacteria_465.jpegsaved
# person172_bacteria_828.jpegsaved
# person158_bacteria_744.jpegsaved
# person85_bacteria_423.jpegsaved
# person113_bacteria_542.jpegsaved
# person138_bacteria_657.jpegsaved
# person121_bacteria_576.jpegsaved
# person146_bacteria_703.jpegsaved
# person152_bacteria_722.jpegsaved
# person120_bacteria_571.jpegsaved
# person83_bacteria_407.jpegsaved
# person119_bacteria_567.jpegsaved
# person152_bacteria_721.jpegsaved
# person53_virus_107.jpegsaved
# person171_bacteria_826.jpegsaved
# person86_bacteria_428.jpegsaved
# person65_virus_123.jpegsaved
# person1_virus_7.jpegsaved
# person130_bacteria_625.jpegsaved
# person10_virus_35.jpegsaved
# person61_virus_118.jpegsaved
# person139_bacteria_665.jpegsaved
# person103_bacteria_490.jpegsaved
# person121_bacteria_579.jpegsaved
# person108_bacteria_511.jpegsaved
# person88_bacteria_437.jpegsaved
# person1634_virus_2830.jpegsaved
# person86_bacteria_429.jpegsaved
# person72_virus_133.jpegsaved
# person136_bacteria_648.jpegsaved
# person120_bacteria_573.jpegsaved
# person48_virus_100.jpegsaved
# person1618_virus_2805.jpegsaved
# person134_bacteria_641.jpegsaved
# person94_bacteria_458.jpegsaved
# person101_bacteria_484.jpegsaved
# person100_bacteria_478.jpegsaved
# person130_bacteria_626.jpegsaved
# person1678_virus_2895.jpegsaved
# person52_virus_106.jpegsaved
# person78_bacteria_378.jpegsaved
# person137_bacteria_655.jpegsaved
# person142_bacteria_684.jpegsaved
# person139_bacteria_664.jpegsaved
# person104_bacteria_491.jpegsaved
# person94_bacteria_456.jpegsaved
# person141_bacteria_676.jpegsaved
# person71_virus_131.jpegsaved
# person1_virus_12.jpegsaved
# person1_virus_6.jpegsaved
# person1665_virus_2878.jpegsaved
# person155_bacteria_730.jpegsaved
# person161_bacteria_757.jpegsaved
# person41_virus_88.jpegsaved
# person152_bacteria_720.jpegsaved
# person143_bacteria_688.jpegsaved
# person49_virus_101.jpegsaved
# person1680_virus_2897.jpegsaved
# person132_bacteria_632.jpegsaved
# person117_bacteria_556.jpegsaved
# person78_bacteria_382.jpegsaved
# person60_virus_117.jpegsaved
# person109_bacteria_522.jpegsaved
# person1670_virus_2886.jpegsaved
# person1673_virus_2889.jpegsaved
# person62_virus_119.jpegsaved
# person144_bacteria_690.jpegsaved
# person47_virus_99.jpegsaved
# person101_bacteria_486.jpegsaved
# person100_bacteria_481.jpegsaved
# person145_bacteria_696.jpegsaved
# person1620_virus_2807.jpegsaved
# person119_bacteria_566.jpegsaved
# person3_virus_16.jpegsaved
# person89_bacteria_440.jpegsaved
# person130_bacteria_628.jpegsaved
# person8_virus_27.jpegsaved
# person1625_virus_2817.jpegsaved
# person100_bacteria_475.jpegsaved
# person159_bacteria_747.jpegsaved
# person108_bacteria_506.jpegsaved
# person122_bacteria_583.jpegsaved
# person8_virus_28.jpegsaved
# person81_bacteria_396.jpegsaved
# person138_bacteria_658.jpegsaved
# person11_virus_38.jpegsaved
# person80_bacteria_390.jpegsaved
# person146_bacteria_700.jpegsaved
# person91_bacteria_449.jpegsaved
# person85_bacteria_419.jpegsaved
# person100_bacteria_479.jpegsaved
# person35_virus_80.jpegsaved
# person133_bacteria_633.jpegsaved
# person1667_virus_2881.jpegsaved
# person1_virus_13.jpegsaved
# person42_virus_89.jpegsaved
# person14_virus_44.jpegsaved
# person133_bacteria_637.jpegsaved
# person59_virus_116.jpegsaved
# person1616_virus_2802.jpegsaved
# person174_bacteria_832.jpegsaved
# person80_bacteria_393.jpegsaved
# person119_bacteria_565.jpegsaved
# person1671_virus_2887.jpegsaved
# person113_bacteria_541.jpegsaved
# person134_bacteria_640.jpegsaved
# person36_virus_81.jpegsaved
# person118_bacteria_559.jpegsaved
# person135_bacteria_647.jpegsaved
# person93_bacteria_453.jpegsaved
# person83_bacteria_414.jpegsaved
# person1623_virus_2813.jpegsaved
# person146_bacteria_704.jpegsaved
# person63_virus_121.jpegsaved
# person1657_virus_2864.jpegsaved
# person108_bacteria_507.jpegsaved
# person141_bacteria_681.jpegsaved
# person88_bacteria_439.jpegsaved
# person50_virus_102.jpegsaved
# person108_bacteria_504.jpegsaved
# person24_virus_58.jpegsaved
# person100_bacteria_480.jpegsaved
# person133_bacteria_638.jpegsaved
# person122_bacteria_585.jpegsaved
# person141_bacteria_670.jpegsaved
# person1679_virus_2896.jpegsaved
# person134_bacteria_642.jpegsaved
# person124_bacteria_590.jpegsaved
# person111_bacteria_537.jpegsaved
# person99_bacteria_474.jpegsaved
# person44_virus_94.jpegsaved
# person140_bacteria_668.jpegsaved
# person81_bacteria_397.jpegsaved
# person1660_virus_2869.jpegsaved
# person1647_virus_2848.jpegsaved
# person1682_virus_2899.jpegsaved
# person78_bacteria_387.jpegsaved
# person124_bacteria_589.jpegsaved
# person1622_virus_2810.jpegsaved
# person109_bacteria_517.jpegsaved
# person128_bacteria_608.jpegsaved
# person83_bacteria_412.jpegsaved
# person18_virus_49.jpegsaved
# person91_bacteria_445.jpegsaved
# person142_bacteria_683.jpegsaved
# person100_bacteria_482.jpegsaved
# person142_bacteria_682.jpegsaved
# person1612_virus_2797.jpegsaved
# person175_bacteria_834.jpegsaved
# person151_bacteria_718.jpegsaved
# person81_bacteria_398.jpegsaved
# person25_virus_59.jpegsaved
# person70_virus_130.jpegsaved
# person101_bacteria_485.jpegsaved
# person38_virus_83.jpegsaved
# person1649_virus_2850.jpegsaved
# person1631_virus_2826.jpegsaved
# person53_virus_108.jpegsaved
# person78_bacteria_380.jpegsaved
# person139_bacteria_661.jpegsaved
# person1668_virus_2882.jpegsaved
# person109_bacteria_523.jpegsaved
# person21_virus_53.jpegsaved
# person110_bacteria_531.jpegsaved
# person139_bacteria_663.jpegsaved
# person158_bacteria_742.jpegsaved
# person161_bacteria_759.jpegsaved
# person127_bacteria_603.jpegsaved
# person147_bacteria_705.jpegsaved
# person133_bacteria_635.jpegsaved
# person51_virus_105.jpegsaved
# person17_virus_48.jpegsaved
# person44_virus_93.jpegsaved
# person33_virus_72.jpegsaved
# person1629_virus_2823.jpegsaved
# person92_bacteria_451.jpegsaved
# person69_virus_129.jpegsaved
# person1642_virus_2842.jpegsaved
# person54_virus_109.jpegsaved
# person88_bacteria_438.jpegsaved
# person1640_virus_2839.jpegsaved
# person121_bacteria_575.jpegsaved
# person1628_virus_2821.jpegsaved
# person139_bacteria_666.jpegsaved
# person80_bacteria_389.jpegsaved
# person74_virus_135.jpegsaved
# person78_bacteria_381.jpegsaved
# person155_bacteria_731.jpegsaved
# person1674_virus_2890.jpegsaved
# person130_bacteria_627.jpegsaved
# person109_bacteria_513.jpegsaved
# person71_virus_132.jpegsaved
# person136_bacteria_650.jpegsaved
# person96_bacteria_466.jpegsaved
# person109_bacteria_526.jpegsaved
# person34_virus_76.jpegsaved
# person57_virus_113.jpegsaved
# person109_bacteria_527.jpegsaved
# person150_bacteria_717.jpegsaved
# person119_bacteria_568.jpegsaved
# person85_bacteria_422.jpegsaved
# person134_bacteria_643.jpegsaved
# person153_bacteria_726.jpegsaved
# person83_bacteria_411.jpegsaved
# person1675_virus_2891.jpegsaved
# person1651_virus_2855.jpegsaved
# person1_virus_9.jpegsaved
# person104_bacteria_492.jpegsaved
# person1653_virus_2858.jpegsaved
# person76_virus_138.jpegsaved
# person1653_virus_2859.jpegsaved
# person1626_virus_2818.jpegsaved
# person40_virus_87.jpegsaved
# person30_virus_69.jpegsaved
# person112_bacteria_539.jpegsaved
# person157_bacteria_735.jpegsaved
# person126_bacteria_600.jpegsaved
# person127_bacteria_602.jpegsaved
# person150_bacteria_716.jpegsaved
# person81_bacteria_395.jpegsaved
# person126_bacteria_599.jpegsaved
# person136_bacteria_649.jpegsaved
# person113_bacteria_540.jpegsaved
# person1661_virus_2873.jpegsaved
# person109_bacteria_519.jpegsaved
# person124_bacteria_591.jpegsaved
# person124_bacteria_592.jpegsaved
# person39_virus_85.jpegsaved
# person1643_virus_2843.jpegsaved
# person78_bacteria_385.jpegsaved
# person38_virus_84.jpegsaved
# person1633_virus_2829.jpegsaved
# person1627_virus_2819.jpegsaved
# person1662_virus_2875.jpegsaved
# person103_bacteria_488.jpegsaved
# person120_bacteria_570.jpegsaved
# person67_virus_126.jpegsaved
# person15_virus_46.jpegsaved
# person143_bacteria_689.jpegsaved
# person154_bacteria_728.jpegsaved
# person1669_virus_2884.jpegsaved
# person31_virus_70.jpegsaved
# person87_bacteria_434.jpegsaved
# person147_bacteria_707.jpegsaved
# person82_bacteria_405.jpegsaved
# person1669_virus_2885.jpegsaved
# person64_virus_122.jpegsaved
# person161_bacteria_762.jpegsaved
# person1613_virus_2799.jpegsaved
# person122_bacteria_584.jpegsaved
# person37_virus_82.jpegsaved
# person147_bacteria_711.jpegsaved
# person92_bacteria_450.jpegsaved
# person91_bacteria_447.jpegsaved
# person85_bacteria_421.jpegsaved
# person103_bacteria_489.jpegsaved
# person135_bacteria_646.jpegsaved
# person1612_virus_2798.jpegsaved
# person173_bacteria_829.jpegsaved
# person136_bacteria_652.jpegsaved
# person130_bacteria_623.jpegsaved
# person126_bacteria_598.jpegsaved
# person85_bacteria_424.jpegsaved
# person109_bacteria_528.jpegsaved
# person82_bacteria_404.jpegsaved
# person22_virus_54.jpegsaved
# person114_bacteria_545.jpegsaved
# person78_bacteria_386.jpegsaved
# person172_bacteria_827.jpegsaved
# person1_virus_8.jpegsaved
# person1641_virus_2840.jpegsaved
# person43_virus_92.jpegsaved
# person1608_virus_2786.jpegsaved
# person1655_virus_2861.jpegsaved
# person1659_virus_2867.jpegsaved
# person1615_virus_2801.jpegsaved
# person1664_virus_2877.jpegsaved
# person111_bacteria_536.jpegsaved
# person152_bacteria_724.jpegsaved
# NORMAL
# NORMAL2-IM-0369-0001.jpegsaved
# IM-0086-0001.jpegsaved
# NORMAL2-IM-0323-0001.jpegsaved
# IM-0073-0001.jpegsaved
# NORMAL2-IM-0328-0001.jpegsaved
# NORMAL2-IM-0072-0001.jpegsaved
# NORMAL2-IM-0304-0001.jpegsaved
# NORMAL2-IM-0123-0001.jpegsaved
# NORMAL2-IM-0343-0001.jpegsaved
# IM-0075-0001.jpegsaved
# NORMAL2-IM-0329-0001.jpegsaved
# IM-0087-0001.jpegsaved
# NORMAL2-IM-0370-0001.jpegsaved
# IM-0085-0001.jpegsaved
# IM-0095-0001.jpegsaved
# IM-0033-0001-0001.jpegsaved
# NORMAL2-IM-0221-0001.jpegsaved
# NORMAL2-IM-0251-0001.jpegsaved
# NORMAL2-IM-0066-0001.jpegsaved
# IM-0069-0001.jpegsaved
# NORMAL2-IM-0303-0001.jpegsaved
# NORMAL2-IM-0338-0001.jpegsaved
# NORMAL2-IM-0195-0001.jpegsaved
# NORMAL2-IM-0333-0001.jpegsaved
# NORMAL2-IM-0150-0001.jpegsaved
# IM-0010-0001.jpegsaved

# %%
for category in os.listdir(test_path):
    os.chdir(os.path.join(test_path,category))
    pathf = os.path.join("/kaggle/working/chest-xray-pneumonia/chest_xray/train",category)
    os.mkdir(pathf)
    print(category)
    
    for ix in os.listdir(): #Images
            img = cv2.imread(ix)
            img_median = preprocess(img)
            filename1 = str(pathf)+"/"+ix
            filename2 = str(pathf)+"/"+"modified_"+ix
#             cv2.imwrite(filename1,img)
            cv2.imwrite(filename2,img_median) # Saving Modified Image
#             print(str(ix+"saved"))
print("SAVED")
# Out:
# PNEUMONIA
# NORMAL
# SAVED

# %%
import matplotlib.pyplot as plt
img = cv2.imread("/kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1247-0001.jpeg")
plt.imshow(img,cmap='gray')

# %%
img_resized = cv2.resize(img, (224, 224))
img_sharpened = cv2.GaussianBlur(img_resized, (5,5), 0)
img_sharpened = cv2.addWeighted(img_resized, 1.5, img_sharpened, -0.5, 0)
plt.imshow(img_sharpened,cmap='gray')

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=10,
                                   width_shift_range=0.1,
                                   height_shift_range=0.1,
                                   shear_range=0.1,
                                   zoom_range=0.1,
                                   horizontal_flip=True)

val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_path1 = "/kaggle/working/chest-xray-pneumonia/chest_xray/train"
test_path1 = "/kaggle/working/chest-xray-pneumonia/chest_xray/test"
train_generator = train_datagen.flow_from_directory(train_path1,
                                                    target_size=img_size,
                                                    batch_size=batch_size,
                                        
                                                    class_mode='binary')

val_generator = val_datagen.flow_from_directory(val_path,
                                                target_size=img_size,
                                                batch_size=batch_size,
                                                class_mode='binary')

test_generator = test_datagen.flow_from_directory(test_path,
                                                  target_size=img_size,
                                                  batch_size=batch_size,
                                                  class_mode='binary')
# Out:
# Found 624 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %%
#VANILLA NN
model = tf.keras.models.Sequential([
tf.keras.layers.Conv2D(16,kernel_size=(7,7),activation='relu',input_shape=(224,224,3)),
tf.keras.layers.MaxPooling2D(pool_size=(2,2)),
tf.keras.layers.Conv2D(32,kernel_size=(5,5),activation='relu'),
tf.keras.layers.MaxPooling2D(pool_size=(2,2)),
tf.keras.layers.Conv2D(64,kernel_size=(5,5),activation='relu'),
tf.keras.layers.MaxPooling2D(pool_size=(2,2)),
tf.keras.layers.Conv2D(128,kernel_size=(5,5),activation='relu'),
tf.keras.layers.MaxPooling2D(pool_size=(2,2)),
tf.keras.layers.Dropout(0.5),
tf.keras.layers.Flatten(),
tf.keras.layers.Dense(32,activation='relu'),
tf.keras.layers.Dense(1,activation='sigmoid') # whatever is the label, is returned
])
model.compile(loss='binary_crossentropy',optimizer=tf.keras.optimizers.Adam(lr=1e-4),metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 218, 218, 16)      2368
#
#  max_pooling2d (MaxPooling2D  (None, 109, 109, 16)     0
#  )
#
#  conv2d_2 (Conv2D)           (None, 105, 105, 32)      12832
#
#  max_pooling2d_1 (MaxPooling  (None, 52, 52, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 48, 48, 64)        51264
#
#  max_pooling2d_2 (MaxPooling  (None, 24, 24, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 20, 20, 128)       204928
#
#  max_pooling2d_3 (MaxPooling  (None, 10, 10, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 10, 10, 128)       0
#
#  flatten_1 (Flatten)         (None, 12800)             0
#
#  dense_4 (Dense)             (None, 32)                409632
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 681,057
# Trainable params: 681,057
# Non-trainable params: 0
# _________________________________________________________________

# %%
steps_per_epoch = train_generator.n//train_generator.batch_size
validation_steps = val_generator.n//val_generator.batch_size

# train the model
hist = model.fit_generator(train_generator,
          steps_per_epoch=steps_per_epoch,
          epochs=20,
          validation_data=val_generator,
          validation_steps=validation_steps)

# evaluate the model on the test dataset
loss, accuracy = model.evaluate(test_generator, steps=len(test_generator))
print(f'Test accuracy: {accuracy*100:.2f}%')
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:9: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   if __name__ == "__main__":
# Epoch 1/20
# 2023-03-16 00:08:22.973520: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential_2/dropout_2/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 9/9 [==============================] - 20s 879ms/step - loss: 0.7020 - accuracy: 0.5304
# Epoch 2/20
# 9/9 [==============================] - 7s 767ms/step - loss: 0.6687 - accuracy: 0.6250
# Epoch 3/20
# 9/9 [==============================] - 8s 829ms/step - loss: 0.6603 - accuracy: 0.6304
# Epoch 4/20
# 9/9 [==============================] - 7s 818ms/step - loss: 0.6638 - accuracy: 0.6267
# Epoch 5/20
# 9/9 [==============================] - 7s 797ms/step - loss: 0.6617 - accuracy: 0.6214
# Epoch 6/20
# 9/9 [==============================] - 7s 784ms/step - loss: 0.6644 - accuracy: 0.6179
# Epoch 7/20
# 9/9 [==============================] - 7s 830ms/step - loss: 0.6496 - accuracy: 0.6250
# Epoch 8/20
# 9/9 [==============================] - 7s 781ms/step - loss: 0.6303 - accuracy: 0.6198
# Epoch 9/20
# 9/9 [==============================] - 7s 833ms/step - loss: 0.6193 - accuracy: 0.6161
# Epoch 10/20
# 9/9 [==============================] - 8s 891ms/step - loss: 0.5889 - accuracy: 0.6857
# Epoch 11/20
# 9/9 [==============================] - 7s 802ms/step - loss: 0.5636 - accuracy: 0.7250
# Epoch 12/20
# 9/9 [==============================] - 7s 786ms/step - loss: 0.5148 - accuracy: 0.7679
# Epoch 13/20
# 9/9 [==============================] - 7s 805ms/step - loss: 0.5527 - accuracy: 0.7196
# Epoch 14/20
# 9/9 [==============================] - 7s 745ms/step - loss: 0.4742 - accuracy: 0.7679
# Epoch 15/20
# 9/9 [==============================] - 7s 789ms/step - loss: 0.4952 - accuracy: 0.7607
# Epoch 16/20
# 9/9 [==============================] - 7s 795ms/step - loss: 0.4336 - accuracy: 0.8143
# Epoch 17/20
# 9/9 [==============================] - 8s 873ms/step - loss: 0.4149 - accuracy: 0.8018
# Epoch 18/20
# 9/9 [==============================] - 7s 790ms/step - loss: 0.4443 - accuracy: 0.7875
# Epoch 19/20
# 9/9 [==============================] - 7s 738ms/step - loss: 0.3888 - accuracy: 0.8464
# Epoch 20/20
# 9/9 [==============================] - 7s 749ms/step - loss: 0.3929 - accuracy: 0.8125
# 10/10 [==============================] - 9s 833ms/step - loss: 0.3002 - accuracy: 0.8702
# Test accuracy: 87.02%

# %%
plt.plot(hist.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.show()

# %%
plt.plot(hist.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()
